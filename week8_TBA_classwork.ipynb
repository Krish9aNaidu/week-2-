# %% [markdown]
# # Named Entity Recognition

# %% [markdown]
# ## SpaCy

# %%
# !pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in c:\users\geeth\appdata\roaming\python\python311\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (69.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from jinja2->spacy) (2.1.5)

# %% [markdown]
# ## Import SpaCy in English

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      -------------------------------------- 0.1/587.7 MB 787.7 kB/s eta 0:12:26
#      ---------------------------------------- 0.4/587.7 MB 3.0 MB/s eta 0:03:14
#      ---------------------------------------- 1.0/587.7 MB 5.5 MB/s eta 0:01:48
#      ---------------------------------------- 1.6/587.7 MB 7.2 MB/s eta 0:01:22
#      ---------------------------------------- 2.5/587.7 MB 9.9 MB/s eta 0:01:00
#      --------------------------------------- 3.6/587.7 MB 12.1 MB/s eta 0:00:49
#      --------------------------------------- 4.6/587.7 MB 14.1 MB/s eta 0:00:42
#      --------------------------------------- 6.1/587.7 MB 16.2 MB/s eta 0:00:36
#       -------------------------------------- 8.0/587.7 MB 19.8 MB/s eta 0:00:30
#       ------------------------------------- 10.5/587.7 MB 29.7 MB/s eta 0:00:20
#       ------------------------------------- 12.3/587.7 MB 38.5 MB/s eta 0:00:15
#       ------------------------------------- 12.8/587.7 MB 38.5 MB/s eta 0:00:15
#      - ------------------------------------ 15.7/587.7 MB 46.7 MB/s eta 0:00:13
#      - ------------------------------------ 17.7/587.7 MB 50.4 MB/s eta 0:00:12
#      - ------------------------------------ 19.4/587.7 MB 46.7 MB/s eta 0:00:13
#      - ------------------------------------ 20.7/587.7 MB 43.7 MB/s eta 0:00:13
#      - ------------------------------------ 22.5/587.7 MB 43.7 MB/s eta 0:00:13
#      - ------------------------------------ 22.8/587.7 MB 40.9 MB/s eta 0:00:14
#      - ------------------------------------ 23.5/587.7 MB 38.6 MB/s eta 0:00:15
#      - ------------------------------------ 25.9/587.7 MB 36.4 MB/s eta 0:00:16
#      - ------------------------------------ 28.8/587.7 MB 38.5 MB/s eta 0:00:15
#      - ------------------------------------ 30.5/587.7 MB 36.4 MB/s eta 0:00:16
#      -- ----------------------------------- 32.2/587.7 MB 38.5 MB/s eta 0:00:15
#      -- ----------------------------------- 34.0/587.7 MB 50.4 MB/s eta 0:00:11
#      -- ----------------------------------- 36.2/587.7 MB 46.7 MB/s eta 0:00:12
#      -- ----------------------------------- 37.7/587.7 MB 43.5 MB/s eta 0:00:13
#      -- ----------------------------------- 40.1/587.7 MB 43.5 MB/s eta 0:00:13
#      -- ----------------------------------- 42.0/587.7 MB 46.7 MB/s eta 0:00:12
#      -- ----------------------------------- 43.8/587.7 MB 43.5 MB/s eta 0:00:13
#      -- ----------------------------------- 45.2/587.7 MB 43.7 MB/s eta 0:00:13
#      --- ---------------------------------- 47.4/587.7 MB 43.5 MB/s eta 0:00:13
#      --- ---------------------------------- 49.0/587.7 MB 43.5 MB/s eta 0:00:13
#      --- ---------------------------------- 49.5/587.7 MB 40.9 MB/s eta 0:00:14
#      --- ---------------------------------- 51.5/587.7 MB 38.5 MB/s eta 0:00:14
#      --- ---------------------------------- 53.7/587.7 MB 38.5 MB/s eta 0:00:14
#      --- ---------------------------------- 55.8/587.7 MB 40.9 MB/s eta 0:00:13
#      --- ---------------------------------- 57.0/587.7 MB 38.5 MB/s eta 0:00:14
#      --- ---------------------------------- 59.2/587.7 MB 38.6 MB/s eta 0:00:14
#      --- ---------------------------------- 60.8/587.7 MB 40.9 MB/s eta 0:00:13
#      ---- ---------------------------------
7 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  577.2/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  579.4/587.7 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  581.6/587.7 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  583.9/587.7 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  586.0/587.7 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 43.7 MB/s eta 0:00:01
#      -------------------------------------- 587.7/587.7 MB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from en-core-web-lg==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (69.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.5)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)
for token in doc:
    print(token, end="|")
# Out:
# My|best|friend|Ryan|Peters|likes|fancy|adventure|games|.|

# %%
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)
for token in doc:
    print(token, end="|")
# Out:
# My|best|friend|Ryan|Peters|likes|fancy|adventure|games|.|

# %% [markdown]
# ## What are the attributes that SpaCy adds?

# %%
import pandas as pd

def display_nlp(doc, include_punct=False):
    """Generate data frame for visualization of spaCy tokens."""
    rows = []
    for i, t in enumerate(doc):
        if not t.is_punct or include_punct:
            row = {'token': i,  'text': t.text, 'lemma_': t.lemma_, 
                   'is_stop': t.is_stop, 'is_alpha': t.is_alpha,
                   'pos_': t.pos_, 'dep_': t.dep_, 
                   'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
            rows.append(row)
    
    df = pd.DataFrame(rows).set_index('token')
    df.index.name = None
    return df
display_nlp(doc)
# Out:
#         text     lemma_  is_stop  is_alpha   pos_      dep_ ent_type_ ent_iob_
# 0         My         my     True      True   PRON      poss                  O
# 1       best       good    False      True    ADJ      amod                  O
# 2     friend     friend    False      True   NOUN     nsubj                  O
# 3       Ryan       Ryan    False      True  PROPN  compound    PERSON        B
# 4     Peters     Peters    False      True  PROPN     appos    PERSON        I
# 5      likes       like    False      True   VERB      ROOT                  O
# 6      fancy      fancy    False      True    ADJ      amod                  O
# 7  adventure  adventure    False      True   NOUN  compound                  O
# 8      games       game    False      True   NOUN      dobj                  O

# %% [markdown]
# ## Removing Stop words using Spacy

# %%
text = "Dear Ryan, we need to sit down and talk. Regards, Pete"
doc = nlp(text)

non_stop = [t for t in doc if not t.is_stop and not t.is_punct]
print(non_stop)
# Out:
# [Dear, Ryan, need, sit, talk, Regards, Pete]

# %% [markdown]
# ## Find all nouns using Spacy

# %%
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)

nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]
print(nouns)
# Out:
# [friend, Ryan, Peters, adventure, games]

# %% [markdown]
# ## Named Entity Recognition

# %%
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (Ryan Peters, PERSON)

# %% [markdown]
# ## Harder one:

# %%
text = "James O'Neill, chairman of World Cargo Inc, lives in San Francisco." 
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (James O'Neill, PERSON) (World Cargo Inc, ORG) (San Francisco, GPE)

# %% [markdown]
# ## Visualize NERS:

# %%
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James O'Neill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , chairman of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Cargo Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , lives in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %%
# !pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting html5lib
#   Obtaining dependency information for html5lib from https://files.pythonhosted.org/packages/6c/dd/a834df6482147d48e225a49515aabc28974ad5a4ca3215c18a882565b028/html5lib-1.1-py2.py3-none-any.whl.metadata
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.9 in c:\users\geeth\appdata\roaming\python\python311\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/112.2 kB ? eta -:--:--
#    ---------------------------------------- 112.2/112.2 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1

# %% [markdown]
# ## Let’s try a real dataset

# %%
from bs4 import BeautifulSoup
import requests
import re
import spacy

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')  # Changed to 'html.parser' for compatibility
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# Example URL - replace 'https://ieeexplore.ieee.org/Xplore/home.jsp' with any URL you want to scrape
ny_bb = url_to_string('https://blackboard.sacredheart.edu/ultra/institution-page')

# Load spaCy's English language model. 
# Make sure to download the model first using "python -m spacy download en_core_web_sm"
nlp = spacy.load("en_core_web_sm")

# Process the extracted text
article = nlp(ny_bb)

# Output the number of named entities found
print(len(article.ents))

# Optionally, print out each entity
for ent in article.ents:
    print(ent.text, ent.label_)
# Out:
# 16
# JavaScript PRODUCT
# Blackboard PERSON
# Multi-Factor Authentication ORG
# 1 CARDINAL
# Google Authenticator ORG
# Authy PERSON
# 2 Open TIME
# 3 CARDINAL
# Cancel Next Multi-Factor Authentication PERSON
# 6 CARDINAL
# Back Submit Multi-Factor Authentication PERSON
# Done Sign PERSON
# third ORDINAL
# MySHU Portal PERSON
# 1997-2024 DATE
# All Rights Reserved WORK_OF_ART

# %% [markdown]
# ## Have a look at the NERS

# %%
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Blackboard Learn Blackboard Learn ™ Please enable
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JavaScript
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  in your browser for the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blackboard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  application to function. Username Password Forgot Password?
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Multi-Factor Authentication
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Step
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Download and install any authenticator app (e.g. Microsoft Authenticator,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google Authenticator
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , or
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Authy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ) on your phone. Step
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 Open
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  the authenticator app and scan the image below using your phone's camera or copy the key. Open the authenticator app and copy the key below. ${mfaSecretKey} Copy key - Key copied Step
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Press next to enter the code and associate it with your account
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cancel Next Multi-Factor Authentication
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Type the Code Type the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -digit temporary code generated with your authenticator application
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Back Submit Multi-Factor Authentication
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  You are all set You have enabled multi-factor authentication using your authenticator app. We will now ask for a login code anytime you log in. We will now ask for a login code anytime you log in on a device we don't recognize.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Done Sign
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -party account
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MySHU Portal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  View Course Catalog    ©
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1997-2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Blackboard Inc.
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     All Rights Reserved
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# .    Help Privacy and Terms of Use Accessibility </div></span>

# %% [markdown]
# ## Most popular NER types

# %%
from collections import Counter
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'PERSON': 6,
#          'CARDINAL': 3,
#          'ORG': 2,
#          'PRODUCT': 1,
#          'TIME': 1,
#          'ORDINAL': 1,
#          'DATE': 1,
#          'WORK_OF_ART': 1})

# %% [markdown]
# ## Most popular NER

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('JavaScript', 1),
#  ('Blackboard', 1),
#  ('Multi-Factor Authentication', 1),
#  ('1', 1),
#  ('Google Authenticator', 1)]

# %% [markdown]
# ## Let’s pick one sentence to analyze

# %%
sentences = [x for x in article.sents]
print(sentences[1])
# Out:
# Username Password Forgot Password?

# %% [markdown]
# ## NER tags

# %%
displacy.render(nlp(str(sentences[1])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Username Password Forgot Password?</div></span>

# %% [markdown]
# ## Types of words in the sentence

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[1])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Username', 'PROPN', 'Username'),
#  ('Password', 'PROPN', 'Password'),
#  ('Forgot', 'PROPN', 'Forgot'),
#  ('Password', 'PROPN', 'Password')]

# %% [markdown]
# ## Sentence dependency tree

# %%
displacy.render(nlp(str(sentences[2])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2673c49445cb4533879936d20a30b601-0" class="displacy" width="2570" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Multi-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Factor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Authentication</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Step</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Download</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">install</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">any</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">authenticator</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">app (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">e.g.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Microsoft</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Authenticator,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Authenticator,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">Authy)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">phone.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2673c49445cb4533879936d20a30b601-0-0" stroke-width="2px" d="M70,242.0 C70,122.0 280.0,122.0 280.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2673c49445cb4533879936d20a30b601-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,244.0 L62,232.0 78,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2673c49445cb4533879936d20a30b601-0-1" stroke-width="2px" d="M190,242.0 C190,182.0 275.0,182.0 275.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2673c49445cb4533879936d20a30b601-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,244.0 L182,232.0 198,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2673c49445cb4533879936d20a30b601-0-2" stroke-width="2px" d="M310,242.0 C310,62.0 645.0,62.0 645.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2673c49445cb4533879936d20a30b601-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,244.0 L302,232.0 318,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2673c49445cb4533879936d20a30b601-0-3" stroke-width="2px" d="M430,242.0 C430,122.0 640.0,122.0 640.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2673c49445cb4533879936d20a30b601-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,244.0 L422,232.0 438,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2673c49445cb4533879936
